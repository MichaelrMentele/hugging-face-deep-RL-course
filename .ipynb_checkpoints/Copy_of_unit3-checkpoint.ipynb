# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to /private/var/folders/d8/n91dxjpx127f7sdxww2g2m2c0000gn/T/pip-req-build-y9fxh14u
#   Running command git clone -q https://github.com/DLR-RM/rl-baselines3-zoo /private/var/folders/d8/n91dxjpx127f7sdxww2g2m2c0000gn/T/pip-req-build-y9fxh14u
#   Running command git checkout -b update/hf --track origin/update/hf
#   Switched to a new branch 'update/hf'
#   branch 'update/hf' set up to track 'origin/update/hf'.
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting rich
#   Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#      |████████████████████████████████| 240 kB 254 kB/s eta 0:00:01
# Requirement already satisfied: pyyaml>=5.1 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from rl-zoo3==2.0.0a9) (5.4.1)
# Collecting huggingface-sb3>=2.2.1
#   Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      |████████████████████████████████| 413 kB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from rl-zoo3==2.0.0a9) (4.62.1)
# Collecting pytablewriter~=0.64
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 8.7 MB/s eta 0:00:01
# Collecting gym==0.26.2
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting sb3-contrib>=2.0.0a9
#   Downloading sb3_contrib-2.2.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 6.7 MB/s eta 0:00:01
# Collecting importlib-metadata>=4.8.0
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.18.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (1.20.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (1.6.0)
# Collecting gym-notices>=0.0.4
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Collecting huggingface-hub~=0.8
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#      |████████████████████████████████| 311 kB 7.1 MB/s eta 0:00:01
# Collecting wasabi
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0.1-cp38-cp38-macosx_10_9_x86_64.whl (191 kB)
#      |████████████████████████████████| 191 kB 6.8 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (4.7.1)
# Requirement already satisfied: filelock in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.4.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 6.8 MB/s eta 0:00:01
# Requirement already satisfied: requests in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.26.0)
# Requirement already satisfied: packaging>=20.9 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (21.0)
# Requirement already satisfied: zipp>=0.5 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gym==0.26.2->rl-zoo3==2.0.0a9) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.9->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.4.7)
# Collecting pathvalidate<3,>=2.3.0
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (52.0.0.post20210125)
# Collecting DataProperty<2,>=0.55.0
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting typepy[datetime]<2,>=1.2.0
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Collecting tcolorpy<1,>=0.0.5
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting tabledata<2,>=1.3.0
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: chardet<6,>=3.0.4 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (4.0.0)
# Collecting stable-baselines3<3.0,>=2.2.1
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 8.1 MB/s eta 0:00:01
# Collecting gymnasium<0.30,>=0.28.1
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      |████████████████████████████████| 953 kB 5.4 MB/s eta 0:00:01
# Collecting torch>=1.13
#   Downloading torch-2.1.2-cp38-none-macosx_10_9_x86_64.whl (146.7 MB)
#      |████████████████████████████████| 146.7 MB 211 kB/s eta 0:00:012    |███████████████▎                | 69.8 MB 11.1 MB/s eta 0:00:07
# Requirement already satisfied: matplotlib in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.4.2)
# Requirement already satisfied: pandas in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.3.2)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting numpy>=1.18.0
#   Downloading numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
#      |████████████████████████████████| 19.8 MB 5.5 MB/s eta 0:00:01
# Requirement already satisfied: sympy in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.8)
# Requirement already satisfied: jinja2 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.0.1)
# Requirement already satisfied: networkx in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.6.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from jinja2->torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.1.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.10.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from optuna->rl-zoo3==2.0.0a9) (1.4.22)
# Collecting colorlog
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.13.0-py3-none-any.whl (230 kB)
#      |████████████████████████████████| 230 kB 6.1 MB/s eta 0:00:01
# Collecting Mako
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 5.0 MB/s eta 0:00:01
# Collecting importlib-resources
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy>=1.3.0->optuna->rl-zoo3==2.0.0a9) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.26.6)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.1 MB/s eta 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 6.0 MB/s eta 0:00:011
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: mpmath>=0.19 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.2.1)
# Building wheels for collected packages: rl-zoo3, gym
#   Building wheel for rl-zoo3 (PEP 517) ... done
#   Created wheel for rl-zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=76402 sha256=269cdee98cf133bdc2968c5137be79a4ae73f5d28eb2fb769c3840175473dbcc
#   Stored in directory: /private/var/folders/d8/n91dxjpx127f7sdxww2g2m2c0000gn/T/pip-ephem-wheel-cache-af45pqu1/wheels/12/04/74/8dab6db462767d6a4a8e034e42b52b441c12b34a178ac8344d
#   Building wheel for gym (PEP 517) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827620 sha256=b2988c02adbd53793644cbc11fe3b0cf1570fcb4f3454503516157d05eea332e
#   Stored in directory: /Users/michaelmentele/Library/Caches/pip/wheels/17/79/65/7afedc162d858b02708a3b8f7a6dd5b1000dcd5b0f894f7cc1
# Successfully built rl-zoo3 gym
# Installing collected packages: mbstrdecoder, typepy, numpy, importlib-metadata, fsspec, farama-notifications, torch, pyyaml, mdurl, Mako, importlib-resources, gymnasium, DataProperty, wasabi, tcolorpy, tabledata, stable-baselines3, pygments, pathvalidate, markdown-it-py, huggingface-hub, gym-notices, colorlog, alembic, sb3-contrib, rich, pytablewriter, optuna, huggingface-sb3, gym, rl-zoo3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2021.7.0
#     Uninstalling fsspec-2021.7.0:
#       Successfully uninstalled fsspec-2021.7.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.1
#     Uninstalling torch-1.9.1:
#       Successfully uninstalled torch-1.9.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.10.0
#     Uninstalling Pygments-2.10.0:
#       Successfully uninstalled Pygments-2.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.4 which is incompatible.
# Successfully installed DataProperty-1.0.1 Mako-1.3.0 alembic-1.13.0 colorlog-6.8.0 farama-notifications-0.0.4 fsspec-2023.12.2 gym-0.26.2 gym-notices-0.0.8 gymnasium-0.29.1 huggingface-hub-0.19.4 huggingface-sb3-3.0 importlib-metadata-7.0.0 importlib-resources-6.1.1 markdown-it-py-3.0.0 mbstrdecoder-1.1.3 mdurl-0.1.2 numpy-1.24.4 optuna-3.5.0 pathvalidate-2.5.2 pygments-2.17.2 pytablewriter-0.64.2 pyyaml-6.0.1 rich-13.7.0 rl-zoo3-2.0.0a9 sb3-contrib-2.2.1 stable-baselines3-2.2.1 tabledata-1.3.3 tcolorpy-0.1.4 torch-2.1.2 typepy-1.3.2 wasabi-1.1.2

# %% [markdown]
# IF AND ONLY IF THE VERSION ABOVE DOES NOT EXIST ANYMORE. UNCOMMENT AND INSTALL THE ONE BELOW

# %%
#!pip install rl_zoo3==2.0.0a9

# %%
# !brew install swig cmake ffmpeg
# Out:
# Running `brew update --auto-update`...
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:02180ca8b8295422ae84921bcf034b7ee8ce5575488bd5e6a37a192e53cd5d34
# ######################################################################### 100.0%
# ==> Pouring portable-ruby-3.1.4.el_capitan.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 5 taps (homebrew/services, screenplaydev/tap, withgraphite/tap, homebrew/core and homebrew/cask).
# ==> New Formulae
# abi3audit                                python-attrs
# action-validator                         python-boto3
# ain                                      python-botocore
# ali                                      python-brotli
# amass                                    python-cachetools
# ansible@8                                python-chardet
# apkleaks                                 python-charset-normalizer
# appstream                                python-cli-helpers
# argc                                     python-colorama
# asitop                                   python-configargparse
# auditwheel                               python-configobj
# authz0                                   python-cycler
# awscli-local                             python-dateutil
# badkeys                                  python-dicttoxml
# bao                                      python-distlib
# biodiff                                  python-distro
# bkcrack                                  python-docopt
# bob                                      python-filelock
# bomber                                   python-hatch-fancy-pypi-readme
# bounceback                               python-hatch-vcs
# cargo-sweep                              python-hatchling
# cariddi                                  python-idna
# certgraph                                python-jinja
# certsync                                 python-jmespath
# cf2tf                                    python-json5
# cfripper                                 python-kiwisolver
# chainloop-cli                            python-magic
# chainsaw                                 python-mako
# changie                                  python-markdown-it-py
# cherrybomb                               python-matplotlib
# chisel-tunnel                            python-mdurl
# cidr                                     python-mpmath
# cliam                                    python-msgpack
# cloudsplaining                           python-networkx
# crunchy-cli                              python-oauthlib
# csprecon                                 python-openapi3
# daktilo                                  python-pathspec
# dalfox                                   python-pbr
# dcp                                      python-platformdirs
# der-ascii                                python-pluggy
# dicebear                                 python-ply
# diffoci                                  python-prompt-toolkit
# direwolf                                 python-regex
# dockerfile-language-server               python-requests
# dockly                                   python-requests-oauthlib
# doppler                                  python-rich
# drogon                                   python-s3transfer
# eatmemory                                python-setuptools-scm
# faircamp                                 python-sympy
# favirecon                                python-termcolor
# flyscrape                                python-trove-classifiers
# frozen                                   python-urllib3
# gdrive@2                                 python-wcwidth
# geoip2fast                               python-websocket-client
# ghc@9.6                                  python-xlsxwriter
# git-mediate                              qbittorrent-cli
# gitsign                                  rapidfuzz-cpp
# gittuf                                   raven
# glbinding@2                              rdap
# goresym                                  redress
# gossip                                   redwax-tool
# gotpm                                    reflex
# gptline                                  regclient
# graphqlviz                               rekor-cli
# haiti                                    retire
# immer                                    retry
# instaloader                              richgo
# intercept                                ruler
# invoice                                  saf-cli
# jprq                                     scarb
# karmadactl                               scikit-image
# kew                                      scilla
# lager                                    screenplaydev/tap/graphite-alpha
# libconfini                               screenplaydev/tap/graphite-beta
# libcyaml                                 shell2http
# libdicom                                 shellspec
# libdpp                                   sigma-cli
# libjuice                                 signmykey
# libnghttp3                               sigstore
# libsail                                  skate
# mariadb@11.1                             sloth
# mediamtx                                 snakeviz
# memray                                   snyk-cli
# mentat                                   solo2-cli
# minder                                   spglib
# modsurfer                                spicetify-cli
# node@20                                  spidermonkey@91
# noir                                     sqlfmt
# nvimpager                                squealer
# ocaml@4                                  ssh-mitm
# open-simh                                sshportal
# opensca-cli                              tailspin
# opentofu                                 telegram-downloader
# orbuculum                                terraform-local
# osctrl-cli                               texttest
# oslo                                     three-body
# pan                                      tlrc
# patat                                    uvicorn
# patch-package                            vet
# pciutils                                 virtctl
# pdfalyzer                                vulsio-gost
# pdfrip                                   whisper-cpp
# perl-xml-parser                          withgraphite/tap/graphite-alpha
# php@8.2                                  withgraphite/tap/graphite-beta
# phylum-cli                               witness
# pmix                                     wormhole-william
# presenterm                               xeol
# purr                                     xnvme
# python-abseil                            yatas
# python-anytree                           zix
# python-asn1crypto                        zug
# ==> New Casks
# affine                                   mediamate
# amie                                     metamer
# anka-build-cloud-controller              mindmac
# anka-build-cloud-registry                mitmproxy
# batchoutput-pdf                          music-decoy
# bezel                                    navigraph-charts
# brickstore                               navigraph-simlink
# brightintosh                             notes-better
# btp                                      nvs
# cardo-update                             nx-studio
# clibor                                   october
# codewhisperer                            ok-json
# commandpost                              orka3
# deskpad                                  ovito
# deveco-studio                            ovito-pro
# douyin-chat                              proton-drive
# effect-house                             reader
# focusrite-control-2                      rode-central
# fossa                                    screens-assist
# free-podcast-transcription               senabluetoothdevicemanager
# garmin-basecamp                          simplex
# greenery                                 songkong
# gstreamer-development                    spacedrive
# gstreamer-runtime                        timemachinestatus
# hapigo                                   truhu
# hides                                    tunetag
# hoppscotch                               vimcal
# jazz2-resurrection                       wave
# keymapp                                  wiso-steuer-2024
# kuaitie                                  writerside
# libndi                                   xliff-editor
# macgpt                                   xsplit-vcam
# mdb-accdb-viewer
# You have 59 outdated formulae and 1 outdated cask installed.
#
# Warning: Treating cmake as a formula. For the cask, use homebrew/cask/cmake
# cmake 3.27.4 is already installed but outdated (so it will be upgraded).
# ==> Downloading https://ghcr.io/v2/homebrew/core/swig/manifests/4.1.1
# ######################################################################### 100.0%
# ==> Fetching swig
# ==> Downloading https://ghcr.io/v2/homebrew/core/swig/blobs/sha256:8596c81c9bdd3
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cmake/manifests/3.28.0
# ######################################################################### 100.0%
# ==> Fetching cmake
# ==> Downloading https://ghcr.io/v2/homebrew/core/cmake/blobs/sha256:847553448d22
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/6.0_2
# ######################################################################### 100.0%
# ==> Fetching dependencies for ffmpeg: brotli, giflib, highway, imath, jpeg-turbo, libpng, xz, libtiff, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, aribb24, dav1d, freetype, fontconfig, frei0r, gmp, gettext, libtasn1, nettle, p11-kit, openssl@3, libnghttp2, unbound, gnutls, lame, fribidi, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, harfbuzz, libunibreak, libass, libbluray, cjson, libmicrohttpd, mbedtls, librist, libsoxr, libvidstab, libogg, libvorbis, libvpx, opencore-amr, openjpeg, opus, rav1e, libsamplerate, flac, mpg123, libsndfile, rubberband, sdl2, speex, srt, svt-av1, leptonica, libb2, libarchive, pango, tesseract, theora, x264, x265, xvid, libsodium, zeromq and zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-1
# ######################################################################### 100.0%
# ==> Fetching brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:deb010485b7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.1
# ######################################################################### 100.0%
# ==> Fetching giflib
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:84a39bf9c63
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.0.7
# ######################################################################### 100.0%
# ==> Fetching highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/blobs/sha256:27680ef270
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.9
# ######################################################################### 100.0%
# ==> Fetching imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:75ddf0a1eb96
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.0.0
# ######################################################################### 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:9615c98
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.40
# ######################################################################### 100.0%
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:2178ff2980d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.4.5
# ######################################################################### 100.0%
# ==> Fetching xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:bdd5146737d8a84
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.6.0
# ######################################################################### 100.0%
# ==> Fetching libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:a89a267106
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.15
# ######################################################################### 100.0%
# ==> Fetching little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:d6e646
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.2.1
# ######################################################################### 100.0%
# ==> Fetching openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:89082b132c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.3.2
# ######################################################################### 100.0%
# ==> Fetching webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:1acdc37723e07
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.8.2_1-1
# ######################################################################### 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:1093ba2170
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/2.3.1-1
# ######################################################################### 100.0%
# ==> Fetching libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/blobs/sha256:c0e45e64ba
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.8.0
# ######################################################################### 100.0%
# ==> Fetching aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:641c6a30080e42
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/manifests/1.0.4
# ######################################################################### 100.0%
# ==> Fetching aribb24
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/blobs/sha256:1b3810c428
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/manifests/1.3.0
# ######################################################################### 100.0%
# ==> Fetching dav1d
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/blobs/sha256:a7e2fcfb84c8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.2-1
# ######################################################################### 100.0%
# ==> Fetching freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:a8813d5f4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.14.2
# ######################################################################### 100.0%
# ==> Fetching fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:9735684
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/manifests/2.3.2
# ######################################################################### 100.0%
# ==> Fetching frei0r
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/blobs/sha256:72fe8f2e716
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/manifests/6.3.0
# ######################################################################### 100.0%
# ==> Fetching gmp
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/blobs/sha256:e8410d92339535
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.22.4
# ######################################################################### 100.0%
# ==> Fetching gettext
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:a43af8b39c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.19.0
# ######################################################################### 100.0%
# ==> Fetching libtasn1
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/blobs/sha256:7218661c6
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/manifests/3.9.1
# ######################################################################### 100.0%
# ==> Fetching nettle
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/blobs/sha256:1ca02720906
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.25.3
# ######################################################################### 100.0%
# ==> Fetching p11-kit
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/blobs/sha256:c09253484c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.2.0_1
# ######################################################################### 100.0%
# ==> Fetching openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/blobs/sha256:ca779023
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.58.0
# ######################################################################### 100.0%
# ==> Fetching libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:14a0880
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.19.0
# ######################################################################### 100.0%
# ==> Fetching unbound
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/blobs/sha256:906bef01d6
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.8.2
# ######################################################################### 100.0%
# ==> Fetching gnutls
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/blobs/sha256:8b242a4f13f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lame/manifests/3.100
# ######################################################################### 100.0%
# ==> Fetching lame
# ==> Downloading https://ghcr.io/v2/homebrew/core/lame/blobs/sha256:931beb6c95eab
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.13
# ######################################################################### 100.0%
# ==> Fetching fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:4f38b08fce
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.78.3
# ######################################################################### 100.0%
# ==> Fetching glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:740a493df231d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2023.2
# ######################################################################### 100.0%
# ==> Fetching xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:32a25261
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.11
# ######################################################################### 100.0%
# ==> Fetching libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:10a5ba27ae9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.4
# ######################################################################### 100.0%
# ==> Fetching libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:81c4ce16b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.16-1
# ######################################################################### 100.0%
# ==> Fetching libxcb
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:0fe2f8cf12c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.7
# ######################################################################### 100.0%
# ==> Fetching libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:be011cbeead
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.5
# ######################################################################### 100.0%
# ==> Fetching libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:a4623f19de
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.11
# ######################################################################### 100.0%
# ==> Fetching libxrender
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:f61874a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# ######################################################################### 100.0%
# ==> Fetching lzo
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:11b8557744feb2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2-1
# ######################################################################### 100.0%
# ==> Fetching pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:73469a943a0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.18.0
# ######################################################################### 100.0%
# ==> Fetching cairo
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:18232de7a188
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# ######################################################################### 100.0%
# ==> Fetching graphite2
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:afd3067d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/8.3.0
# ######################################################################### 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:1bf9b5df0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/manifests/5.1
# ######################################################################### 100.0%
# ==> Fetching libunibreak
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/blobs/sha256:e785da
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/manifests/0.17.1
# ######################################################################### 100.0%
# ==> Fetching libass
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/blobs/sha256:c948495c4b4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/manifests/1.3.4
# ######################################################################### 100.0%
# ==> Fetching libbluray
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/blobs/sha256:252cb3fc
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/manifests/1.7.16-1
# ######################################################################### 100.0%
# ==> Fetching cjson
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/blobs/sha256:4918ffa1ece9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/manifests/0.9.77
# ######################################################################### 100.0%
# ==> Fetching libmicrohttpd
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/blobs/sha256:a2bd
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.5.1
# ######################################################################### 100.0%
# ==> Fetching mbedtls
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/blobs/sha256:0bc0b0f4e6
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.10
# ######################################################################### 100.0%
# ==> Fetching librist
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/blobs/sha256:7a14f013c7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/manifests/0.1.3-1
# ######################################################################### 100.0%
# ==> Fetching libsoxr
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/blobs/sha256:00d2a53188
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvidstab/manifests/1.1.1
# ######################################################################### 100.0%
# ==> Fetching libvidstab
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvidstab/blobs/sha256:4263aef
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libogg/manifests/1.3.5-2
# ######################################################################### 100.0%
# ==> Fetching libogg
# ==> Downloading https://ghcr.io/v2/homebrew/core/libogg/blobs/sha256:d8591422a6a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvorbis/manifests/1.3.7-1
# ######################################################################### 100.0%
# ==> Fetching libvorbis
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvorbis/blobs/sha256:94aafb16
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvpx/manifests/1.13.1
# ######################################################################### 100.0%
# ==> Fetching libvpx
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvpx/blobs/sha256:20b5db6c221
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/manifests/0.1.6
# ######################################################################### 100.0%
# ==> Fetching opencore-amr
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/blobs/sha256:9c8eb
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/manifests/2.5.0_1
# ######################################################################### 100.0%
# ==> Fetching openjpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/blobs/sha256:7ac174c6d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/opus/manifests/1.4
# ######################################################################### 100.0%
# ==> Fetching opus
# ==> Downloading https://ghcr.io/v2/homebrew/core/opus/blobs/sha256:83d594d4a0255
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.6.6
# ######################################################################### 100.0%
# ==> Fetching rav1e
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/blobs/sha256:5379729bb8dd
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/manifests/0.2.2
# ######################################################################### 100.0%
# ==> Fetching libsamplerate
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/blobs/sha256:7010
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/manifests/1.4.3
# ######################################################################### 100.0%
# ==> Fetching flac
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/blobs/sha256:a38b2616d47bd
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpg123/manifests/1.32.3
# ######################################################################### 100.0%
# ==> Fetching mpg123
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpg123/blobs/sha256:d5b83bc1af0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/manifests/1.2.2-1
# ######################################################################### 100.0%
# ==> Fetching libsndfile
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/blobs/sha256:6dc5dba
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/3.3.0
# ######################################################################### 100.0%
# ==> Fetching rubberband
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/blobs/sha256:6b10db4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.28.5-1
# ######################################################################### 100.0%
# ==> Fetching sdl2
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/blobs/sha256:7186bc4ca35a3
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/manifests/1.2.1
# ######################################################################### 100.0%
# ==> Fetching speex
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/blobs/sha256:7dec70341e9b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/manifests/1.5.3
# ######################################################################### 100.0%
# ==> Fetching srt
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/blobs/sha256:9339ab535392bd
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/manifests/1.8.0
# ######################################################################### 100.0%
# ==> Fetching svt-av1
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/blobs/sha256:868eb71c8d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/manifests/1.83.1
# ######################################################################### 100.0%
# ==> Fetching leptonica
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/blobs/sha256:043c3d7b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/manifests/0.98.1
# ######################################################################### 100.0%
# ==> Fetching libb2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/blobs/sha256:747d5e721f9f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.7.2
# ######################################################################### 100.0%
# ==> Fetching libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/blobs/sha256:d132c0e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.50.14
# ######################################################################### 100.0%
# ==> Fetching pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:cc63add51202
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.3.3
# ######################################################################### 100.0%
# ==> Fetching tesseract
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/blobs/sha256:1de8251f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/theora/manifests/1.1.1-4
# ######################################################################### 100.0%
# ==> Fetching theora
# ==> Downloading https://ghcr.io/v2/homebrew/core/theora/blobs/sha256:53cce2c2f66
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/x264/manifests/r3108
# ######################################################################### 100.0%
# ==> Fetching x264
# ==> Downloading https://ghcr.io/v2/homebrew/core/x264/blobs/sha256:815879af6a928
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/x265/manifests/3.5-1
# ######################################################################### 100.0%
# ==> Fetching x265
# ==> Downloading https://ghcr.io/v2/homebrew/core/x265/blobs/sha256:26943ec04286b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xvid/manifests/1.3.7
# ######################################################################### 100.0%
# ==> Fetching xvid
# ==> Downloading https://ghcr.io/v2/homebrew/core/xvid/blobs/sha256:1ed7392496855
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsodium/manifests/1.0.19
# ######################################################################### 100.0%
# ==> Fetching libsodium
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsodium/blobs/sha256:211da634
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zeromq/manifests/4.3.5_1
# ######################################################################### 100.0%
# ==> Fetching zeromq
# ==> Downloading https://ghcr.io/v2/homebrew/core/zeromq/blobs/sha256:986910eab95
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/manifests/3.0.5
# ######################################################################### 100.0%
# ==> Fetching zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/blobs/sha256:a52f302fda0d8
# ######################################################################### 100.0%
# ==> Fetching ffmpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/blobs/sha256:e17fbb073d2
# ######################################################################### 100.0%
# ==> Pouring swig--4.1.1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/swig/4.1.1: 775 files, 5.6MB
# ==> Running `brew cleanup swig`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Upgrading cmake
#   3.27.4 -> 3.28.0
#
# ==> Pouring cmake--3.28.0.sonoma.bottle.tar.gz
# ==> Caveats
# To install the CMake documentation, run:
#   brew install cmake-docs
#
# Emacs Lisp files have been installed to:
#   /usr/local/share/emacs/site-lisp/cmake
# ==> Summary
# 🍺  /usr/local/Cellar/cmake/3.28.0: 3,329 files, 58.4MB
# ==> Running `brew cleanup cmake`...
# Removing: /usr/local/Cellar/cmake/3.27.4... (3,285 files, 59.0MB)
# ==> Installing dependencies for ffmpeg: brotli, giflib, highway, imath, jpeg-turbo, libpng, xz, libtiff, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, aribb24, dav1d, freetype, fontconfig, frei0r, gmp, gettext, libtasn1, nettle, p11-kit, openssl@3, libnghttp2, unbound, gnutls, lame, fribidi, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, harfbuzz, libunibreak, libass, libbluray, cjson, libmicrohttpd, mbedtls, librist, libsoxr, libvidstab, libogg, libvorbis, libvpx, opencore-amr, openjpeg, opus, rav1e, libsamplerate, flac, mpg123, libsndfile, rubberband, sdl2, speex, srt, svt-av1, leptonica, libb2, libarchive, pango, tesseract, theora, x264, x265, xvid, libsodium, zeromq and zimg
# ==> Installing ffmpeg dependency: brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/565098509cdfa90593ec9a41b41239f073843f88caed60ddaa3e6194ac4defda--brotli-1.1.0-1.bottle_manifest.json
# ==> Pouring brotli--1.1.0.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/brotli/1.1.0: 24 files, 967.3KB
# ==> Installing ffmpeg dependency: giflib
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/51910e68b838a5c62c91c9352172d516e77a3c3c1a59a2cebaffc3f64f46adf4--giflib-5.2.1.bottle_manifest.json
# ==> Pouring giflib--5.2.1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/giflib/5.2.1: 19 files, 518.5KB
# ==> Installing ffmpeg dependency: highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.0.7
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/310f2f4bf70e1090998016b5441a741a6cf7f895932c5b664e8fb74f236e5401--highway-1.0.7.bottle_manifest.json
# ==> Pouring highway--1.0.7.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/highway/1.0.7: 65 files, 5.6MB
# ==> Installing ffmpeg dependency: imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.9
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/a1667dc9df99f63d77a45c556d56932eab576af5c24e955461c65629589d7628--imath-3.1.9.bottle_manifest.json
# ==> Pouring imath--3.1.9.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/imath/3.1.9: 49 files, 931.3KB
# ==> Installing ffmpeg dependency: jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.0.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/325e745bcb7840d6a83df7bfcafaa4dbc30b29140f252fb82b7714493df29d6d--jpeg-turbo-3.0.0.bottle_manifest.json
# ==> Pouring jpeg-turbo--3.0.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/jpeg-turbo/3.0.0: 44 files, 4.8MB
# ==> Installing ffmpeg dependency: libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.40
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/d2caacc64e32be045b902fa78d2bb4aea7fba8f088cef85cd34b1beab15b755a--libpng-1.6.40.bottle_manifest.json
# ==> Pouring libpng--1.6.40.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/libpng/1.6.40: 27 files, 1.3MB
# ==> Installing ffmpeg dependency: xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.4.5
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/4e81fda476fb634a7e1ac650019bfe768a65d6c387015992df4cd75adf9b3fce--xz-5.4.5.bottle_manifest.json
# ==> Pouring xz--5.4.5.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/xz/5.4.5: 163 files, 2.6MB
# ==> Installing ffmpeg dependency: libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.6.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/9c8455a2f6bcea7bf3e3461218fba309141b0b0553b6e1afc5fe64e63caccff3--libtiff-4.6.0.bottle_manifest.json
# ==> Pouring libtiff--4.6.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/libtiff/4.6.0: 414 files, 6.6MB
# ==> Installing ffmpeg dependency: little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.15
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/272d59128e963c029ee4be014a1cb85b12a790601ded962689c83e6190ecb0bf--little-cms2-2.15.bottle_manifest.json
# ==> Pouring little-cms2--2.15.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/little-cms2/2.15: 21 files, 1.3MB
# ==> Installing ffmpeg dependency: openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.2.1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/5b8bbf02d04feb2a6e9c578e606f8aeacce2f261c79900426f7bc1d2b0c1717e--openexr-3.2.1.bottle_manifest.json
# ==> Pouring openexr--3.2.1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/openexr/3.2.1: 204 files, 7.6MB
# ==> Installing ffmpeg dependency: webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.3.2
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/952907f186b4d32b3e43b7af1c9e93bd484f9b61db1adb22b5fb4a5361cdd0e9--webp-1.3.2.bottle_manifest.json
# ==> Pouring webp--1.3.2.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/webp/1.3.2: 63 files, 2.5MB
# ==> Installing ffmpeg dependency: jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.8.2_1-1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/9ac42aa48e4d7c592c96fc42c145387ba2229a073591c5a92c1a094f779afc3a--jpeg-xl-0.8.2_1-1.bottle_manifest.json
# ==> Pouring jpeg-xl--0.8.2_1.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/jpeg-xl/0.8.2_1: 43 files, 21.8MB
# ==> Installing ffmpeg dependency: libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/2.3.1-1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/2c60c744c64777df8cb83e3ae4115190f469b9e67e7d671d413220c0f4f3df55--libvmaf-2.3.1-1.bottle_manifest.json
# ==> Pouring libvmaf--2.3.1.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/libvmaf/2.3.1: 234 files, 7.2MB
# ==> Installing ffmpeg dependency: aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.8.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/dfcc96b72b82ea2a86a94a9b6348b3fe1084e7459818a04dd86a321d7f8908e1--aom-3.8.0.bottle_manifest.json
# ==> Pouring aom--3.8.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/aom/3.8.0: 23 files, 13.0MB
# ==> Installing ffmpeg dependency: aribb24
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/manifests/1.0.4
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/60185994f1623d662ea1959234838b47c2b4b891760a6b2af42d1cd3b36f2c0f--aribb24-1.0.4.bottle_manifest.json
# ==> Pouring aribb24--1.0.4.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/aribb24/1.0.4: 14 files, 201.6KB
# ==> Installing ffmpeg dependency: dav1d
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/manifests/1.3.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/4e106d7127704beed4209c5ccd8dfa465c085ca0451942b019b08c6c647609e7--dav1d-1.3.0.bottle_manifest.json
# ==> Pouring dav1d--1.3.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/dav1d/1.3.0: 15 files, 2.3MB
# ==> Installing ffmpeg dependency: freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.2-1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/8d6ca45fa8766fb544a5e6dbc76f0a68568656ab4fe1e837704491bb24e3035d--freetype-2.13.2-1.bottle_manifest.json
# ==> Pouring freetype--2.13.2.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/freetype/2.13.2: 67 files, 2.5MB
# ==> Installing ffmpeg dependency: fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.14.2
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/661b3d30dc143679f93265d36ce47323212b212b53bb099e319b0dba9c05594e--fontconfig-2.14.2.bottle_manifest.json
# ==> Pouring fontconfig--2.14.2.sonoma.bottle.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /usr/local/Cellar/fontconfig/2.14.2/bin/fc-cache -frv
# 🍺  /usr/local/Cellar/fontconfig/2.14.2: 88 files, 2.2MB
# ==> Installing ffmpeg dependency: frei0r
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/manifests/2.3.2
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/91852d64b8d97723ec1a57089ba9f5a9eeff095850909578506626bdd7ec1913--frei0r-2.3.2.bottle_manifest.json
# ==> Pouring frei0r--2.3.2.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/frei0r/2.3.2: 154 files, 5.5MB
# ==> Installing ffmpeg dependency: gmp
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/manifests/6.3.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/70a72a71216843d66a953c06ff6337445ce9bc94fae9f0e301e2f59005274a8e--gmp-6.3.0.bottle_manifest.json
# ==> Pouring gmp--6.3.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/gmp/6.3.0: 21 files, 3.3MB
# ==> Installing ffmpeg dependency: gettext
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.22.4
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/3ceb9457127eaa7378dd80ed256098ffb391e2350069becb25cfe2a14f0b7d6d--gettext-0.22.4.bottle_manifest.json
# ==> Pouring gettext--0.22.4.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/gettext/0.22.4: 2,042 files, 23.7MB
# ==> Installing ffmpeg dependency: libtasn1
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.19.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/8abecce04f40738bc8a6921a6b96d847ea5c9759185d4bd9c7c9b5fb4922c375--libtasn1-4.19.0.bottle_manifest.json
# ==> Pouring libtasn1--4.19.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/libtasn1/4.19.0: 61 files, 657.5KB
# ==> Installing ffmpeg dependency: nettle
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/manifests/3.9.1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/a02ae3a1ecc6cff56e632f6452fd57f3fa72be16cde0b69e5b47747283fd3f6b--nettle-3.9.1.bottle_manifest.json
# ==> Pouring nettle--3.9.1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/nettle/3.9.1: 94 files, 2.6MB
# ==> Installing ffmpeg dependency: p11-kit
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.25.3
# ...
# ==> Upgrading fb303
#   2023.08.28.00 -> 2023.12.04.00
#
# ==> Pouring fb303--2023.12.04.00.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/fb303/2023.12.04.00: 57 files, 5.5MB
# ==> Running `brew cleanup fb303`...
# Removing: /usr/local/Cellar/fb303/2023.08.28.00... (57 files, 3.6MB)
# ==> Upgrading llm
#   0.8 -> 0.12
#
# ==> Installing dependencies for llm: pygments, python-certifi, python-click, six, python-dateutil, python-pluggy, python-setuptools, python-tabulate, python-typing-extensions, pyyaml and sqlite-utils
# ==> Installing llm dependency: pygments
# ==> Downloading https://ghcr.io/v2/homebrew/core/pygments/manifests/2.17.2
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/e45a86b1224315fd3e27d6657f550c920e0d84e68448093c9a64fe83144e62f3--pygments-2.17.2.bottle_manifest.json
# ==> Pouring pygments--2.17.2.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/pygments/2.17.2: 670 files, 8.4MB
# ==> Installing llm dependency: python-certifi
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-certifi/manifests/2023.1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/0de846edba62cfa8858c05c32e7d5a548a1e7ebecc133c43d5b0c29bc0d0c670--python-certifi-2023.11.17-1.bottle_manifest.json
# ==> Pouring python-certifi--2023.11.17.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/python-certifi/2023.11.17: 30 files, 24.3KB
# ==> Installing llm dependency: python-click
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-click/manifests/8.1.7_1-
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/b9a24d787ce77d3c4e4fb32f7d07de7946d2749fc2dad28d410e6383441a998b--python-click-8.1.7_1-1.bottle_manifest.json
# ==> Pouring python-click--8.1.7_1.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/python-click/8.1.7_1: 55 files, 745.4KB
# ==> Installing llm dependency: six
# ==> Downloading https://ghcr.io/v2/homebrew/core/six/manifests/1.16.0_4
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/d658d3e82cd694d7f522b1df4eec1d883dcec244931403fd77c6a0d75ad71193--six-1.16.0_4.bottle_manifest.json
# ==> Pouring six--1.16.0_4.all.bottle.tar.gz
# 🍺  /usr/local/Cellar/six/1.16.0_4: 20 files, 122.4KB
# ==> Installing llm dependency: python-dateutil
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-dateutil/manifests/2.8.2
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/e550131925667be77fb15f47affdc11335cc9e47f97c70e8d7ebffd9fa60be09--python-dateutil-2.8.2-1.bottle_manifest.json
# ==> Pouring python-dateutil--2.8.2.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/python-dateutil/2.8.2: 62 files, 961.6KB
# ==> Installing llm dependency: python-pluggy
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-pluggy/manifests/1.3.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/f76394dc9e8c8f28f51cc379fc46a77e0a72fd24b839cc7c6b51f36ba42342ed--python-pluggy-1.3.0.bottle_manifest.json
# ==> Pouring python-pluggy--1.3.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/python-pluggy/1.3.0: 37 files, 148.9KB
# ==> Installing llm dependency: python-setuptools
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-setuptools/manifests/69.
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/09482f31ffff76933073fa42dec97d769d75b19d88616d802de5e36dc20b44ec--python-setuptools-69.0.2.bottle_manifest.json
# ==> Pouring python-setuptools--69.0.2.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/python-setuptools/69.0.2: 262 files, 2.9MB
# ==> Installing llm dependency: python-tabulate
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-tabulate/manifests/0.9.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/e1eca57de55b30cec7498ca187a7367db82bdc50dcd6df4226578eb5554c9b1d--python-tabulate-0.9.0_1-1.bottle_manifest.json
# ==> Pouring python-tabulate--0.9.0_1.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/python-tabulate/0.9.0_1: 29 files, 298.6KB
# ==> Installing llm dependency: python-typing-extensions
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-typing-extensions/manife
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/5ef2cfa9f8e4ad83040913721c73ca07490d209d49ffd3f1c00d8f4a211cd68a--python-typing-extensions-4.9.0.bottle_manifest.json
# ==> Pouring python-typing-extensions--4.9.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/python-typing-extensions/4.9.0: 21 files, 286.3KB
# ==> Installing llm dependency: pyyaml
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyyaml/manifests/6.0.1_1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/bb167293fae0bea9e7a2acd7496bdc04de8fd1d22a0d4c554a42477cda37397a--pyyaml-6.0.1_1.bottle_manifest.json
# ==> Pouring pyyaml--6.0.1_1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/pyyaml/6.0.1_1: 86 files, 1.5MB
# ==> Installing llm dependency: sqlite-utils
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite-utils/manifests/3.36
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/ebd4cf68a9218b060bf286360d836ece544d6ca37c907e96b3ea22f072734f96--sqlite-utils-3.36.bottle_manifest.json
# ==> Installing dependencies for sqlite-utils: ca-certificates
# ==> Installing sqlite-utils dependency: ca-certificates
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2023-
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/13aa86e429e05d02a76005d1881eaf625091a5ac4dc7d7674c706d12ba48796a--ca-certificates-2023-12-12.bottle_manifest.json
# ==> Pouring ca-certificates--2023-12-12.all.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /usr/local/Cellar/ca-certificates/2023-12-12: 3 files, 226.7KB
# ==> Installing sqlite-utils
# ==> Pouring sqlite-utils--3.36.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/sqlite-utils/3.36: 48 files, 334.5KB
# ==> Installing llm
# ==> Pouring llm--0.12.sonoma.bottle.1.tar.gz
# ==> Caveats
# zsh completions have been installed to:
#   /usr/local/share/zsh/site-functions
# ==> Summary
# 🍺  /usr/local/Cellar/llm/0.12: 569 files, 9.5MB
# ==> Running `brew cleanup llm`...
# Removing: /usr/local/Cellar/llm/0.8... (914 files, 13.8MB)
# ==> Upgrading node
#   20.5.1 -> 21.4.0
#
# ==> Installing dependencies for node: c-ares and libuv
# ==> Installing node dependency: c-ares
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/manifests/1.23.0-1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/a8afe4212b847293127b1888bc834832c2c77c9e11294fcd3da8c2e19794a376--c-ares-1.23.0-1.bottle_manifest.json
# ==> Pouring c-ares--1.23.0.sonoma.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/c-ares/1.23.0: 155 files, 995.6KB
# ==> Installing node dependency: libuv
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/manifests/1.47.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/bfee09d0f61c35b1a86c5b7a0f6b2f9e0a8b18a81bbd065f6eea7054b543f3ea--libuv-1.47.0.bottle_manifest.json
# ==> Pouring libuv--1.47.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/libuv/1.47.0: 19 files, 1MB
# ==> Installing node
# ==> Pouring node--21.4.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/node/21.4.0: 2,233 files, 64.4MB
# ==> Running `brew cleanup node`...
# Removing: /usr/local/Cellar/node/20.5.1... (2,356 files, 58MB)
# ==> Upgrading open-mpi
#   4.1.5 -> 5.0.0
#
# ==> Installing dependencies for open-mpi: mpfr, hwloc and pmix
# ==> Installing open-mpi dependency: mpfr
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpfr/manifests/4.2.1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/a2a3424f4974f6febfa0334a93f35f508eaef3f4ad04320f73d9498302295635--mpfr-4.2.1.bottle_manifest.json
# ==> Pouring mpfr--4.2.1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/mpfr/4.2.1: 30 files, 3.1MB
# ==> Installing open-mpi dependency: hwloc
# ==> Downloading https://ghcr.io/v2/homebrew/core/hwloc/manifests/2.10.0
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/892465425f662087a8b4b7c148c9fd17f1ac8c7824d3e8d2d3ce3459a396b0dd--hwloc-2.10.0.bottle_manifest.json
# ==> Pouring hwloc--2.10.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/hwloc/2.10.0: 969 files, 10.3MB
# ==> Installing open-mpi dependency: pmix
# ==> Downloading https://ghcr.io/v2/homebrew/core/pmix/manifests/4.2.7
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/11c812d0330b39a092da542c6ed56548b765725e14bf913b80c3f09de70060d5--pmix-4.2.7.bottle_manifest.json
# ==> Pouring pmix--4.2.7.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/pmix/4.2.7: 351 files, 8.4MB
# ==> Installing open-mpi
# ==> Pouring open-mpi--5.0.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/open-mpi/5.0.0: 2,751 files, 75.5MB
# ==> Running `brew cleanup open-mpi`...
# Removing: /usr/local/Cellar/open-mpi/4.1.5... (759 files, 15.7MB)
# ==> Upgrading python@3.10
#   3.10.13 -> 3.10.13_1
#
# ==> Pouring python@3.10--3.10.13_1.sonoma.bottle.tar.gz
# ==> /usr/local/Cellar/python@3.10/3.10.13_1/bin/python3.10 -Im ensurepip
# ==> /usr/local/Cellar/python@3.10/3.10.13_1/bin/python3.10 -Im pip install -v --
# 🍺  /usr/local/Cellar/python@3.10/3.10.13_1: 3,096 files, 56.0MB
# ==> Running `brew cleanup python@3.10`...
# Removing: /usr/local/Cellar/python@3.10/3.10.13... (3,183 files, 57.0MB)
# ==> Upgrading python@3.11
#   3.11.5 -> 3.11.6_1
#
# ==> Pouring python@3.11--3.11.6_1.sonoma.bottle.tar.gz
# ==> /usr/local/Cellar/python@3.11/3.11.6_1/bin/python3.11 -Im ensurepip
# ==> /usr/local/Cellar/python@3.11/3.11.6_1/bin/python3.11 -Im pip install -v --n
# 🍺  /usr/local/Cellar/python@3.11/3.11.6_1: 3,284 files, 61.1MB
# ==> Running `brew cleanup python@3.11`...
# Removing: /usr/local/Cellar/python@3.11/3.11.5... (3,312 files, 61.8MB)
# ==> Upgrading rust
#   1.72.0_1 -> 1.74.0
#
# ==> Installing dependencies for rust: libgit2
# ==> Installing rust dependency: libgit2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libgit2/manifests/1.7.1
# Already downloaded: /Users/michaelmentele/Library/Caches/Homebrew/downloads/1b309c0d2e280bfce9151bfc58b4b2d18986fd471ee65e4585b6dc341fe347da--libgit2-1.7.1.bottle_manifest.json
# ==> Pouring libgit2--1.7.1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/libgit2/1.7.1: 104 files, 4.5MB
# ==> Installing rust
# ==> Pouring rust--1.74.0.sonoma.bottle.2.tar.gz
# ==> Caveats
# zsh completions have been installed to:
#   /usr/local/share/zsh/site-functions
# ==> Summary
# 🍺  /usr/local/Cellar/rust/1.74.0: 39,025 files, 968.3MB
# ==> Running `brew cleanup rust`...
# Removing: /usr/local/Cellar/rust/1.72.0_1... (38,318 files, 845.5MB)
# Removing: /Users/michaelmentele/Library/Caches/Homebrew/rust--1.72.0_1... (153.2MB)
# ==> Upgrading watchman
#   2023.08.28.00 -> 2023.12.04.00
#
# ==> Pouring watchman--2023.12.04.00.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/watchman/2023.12.04.00: 22 files, 17.0MB
# ==> Running `brew cleanup watchman`...
# Removing: /usr/local/Cellar/watchman/2023.08.28.00... (22 files, 14.7MB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /Users/michaelmentele/Library/Caches/Homebrew/abseil--20230802.0... (1.5MB)
# Removing: /Users/michaelmentele/Library/Caches/Homebrew/aichat--0.8.0... (3.6MB)
# Removing: /usr/local/Cellar/boost/1.78.0_1... (15,400 files, 463MB)
# Removing: /usr/local/Cellar/boost/1.81.0... (15,831 files, 482.1MB)
# Removing: /usr/local/Cellar/boost/1.82.0_1... (16,057 files, 491.9MB)
# Removing: /usr/local/Cellar/brotli/1.0.9... (25 files, 2.3MB)
# Removing: /usr/local/Cellar/c-ares/1.18.1_1... (87 files, 645.3KB)
# Removing: /usr/local/Cellar/c-ares/1.19.1... (87 files, 661KB)
# Removing: /usr/local/Cellar/ca-certificates/2022-04-26... (3 files, 215.6KB)
# Removing: /usr/local/Cellar/ca-certificates/2022-10-11... (3 files, 225.5KB)
# Removing: /usr/local/Cellar/ca-certificates/2023-08-22... (3 files, 221.6KB)
# Removing: /usr/local/Cellar/double-conversion/3.2.0... (26 files, 242.3KB)
# Removing: /usr/local/Cellar/double-conversion/3.2.1... (26 files, 242.3KB)
# Removing: /usr/local/Cellar/fmt/10.1.0... (27 files, 1.1MB)
# Removing: /usr/local/Cellar/fmt/8.1.1_1... (27 files, 1MB)
# Removing: /usr/local/Cellar/fmt/9.1.0... (27 files, 1MB)
# Removing: /usr/local/Cellar/gettext/0.21.1... (1,983 files, 20.3MB)
# Removing: /Users/michaelmentele/Library/Caches/Homebrew/gh--2.36.0... (10.4MB)
# Removing: /Users/michaelmentele/Library/Caches/Homebrew/git--2.42.0... (18.1MB)
# Removing: /usr/local/Cellar/gmp/6.2.1_1... (21 files, 3.3MB)
# Removing: /usr/local/Cellar/hwloc/2.7.0... (964 files, 10.2MB)
# Removing: /usr/local/Cellar/hwloc/2.9.0... (968 files, 10.5MB)
# Removing: /usr/local/Cellar/hwloc/2.9.2... (969 files, 10.5MB)
# Removing: /usr/local/Cellar/icu4c/70.1... (261 files, 74.4MB)
# Removing: /usr/local/Cellar/icu4c/71.1... (262 files, 76.2MB)
# Removing: /usr/local/Cellar/isl/0.24... (73 files, 7.3MB)
# Removing: /usr/local/Cellar/isl/0.25... (73 files, 7.4MB)
# Removing: /usr/local/Cellar/libevent/2.1.12... (57 files, 2MB)
# Removing: /usr/local/Cellar/liblinear/2.45... (9 files, 335.3KB)
# Removing: /usr/local/Cellar/libnghttp2/1.47.0... (13 files, 678.2KB)
# Removing: /usr/local/Cellar/libnghttp2/1.51.0... (13 files, 721.9KB)
# Removing: /usr/local/Cellar/libnghttp2/1.55.1... (13 files, 711.4KB)
# Removing: /usr/local/Cellar/libsodium/1.0.18_1... (73 files, 1MB)
# Removing: /usr/local/Cellar/libuv/1.44.1_1... (49 files, 3.5MB)
# Removing: /usr/local/Cellar/libuv/1.44.2... (51 files, 3.5MB)
# Removing: /usr/local/Cellar/libuv/1.46.0... (47 files, 3MB)
# Removing: /usr/local/Cellar/mpfr/4.1.0... (30 files, 5.2MB)
# Removing: /usr/local/Cellar/mpfr/4.2.0... (30 files, 3MB)
# Removing: /usr/local/Cellar/mpfr/4.2.0-p12... (30 files, 3MB)
# Removing: /usr/local/Cellar/openssl@3/3.1.2... (6,495 files, 30.0MB)
# Removing: /Users/michaelmentele/Library/Caches/Homebrew/protobuf--24.3... (2.9MB)
# Removing: /usr/local/Cellar/pygments/2.16.1... (656 files, 8.3MB)
# Removing: /usr/local/Cellar/python-certifi/2023.7.22... (36 files, 31.7KB)
# Removing: /usr/local/Cellar/python-tabulate/0.9.0... (29 files, 298.5KB)
# Removing: /usr/local/Cellar/python-typing-extensions/4.7.1... (22 files, 415.3KB)
# Removing: /usr/local/Cellar/pyyaml/6.0.1... (76 files, 1.3MB)
# Removing: /usr/local/Cellar/readline/8.2.1... (50 files, 1.7MB)
# Removing: /usr/local/Cellar/six/1.16.0_3... (21 files, 167.8KB)
# Removing: /usr/local/Cellar/snappy/1.1.9... (18 files, 147.5KB)
# Removing: /usr/local/Cellar/sqlite/3.40.1... (11 files, 4.4MB)
# Removing: /usr/local/Cellar/sqlite/3.43.0... (11 files, 4.5MB)
# Removing: /usr/local/Cellar/xz/5.2.5... (95 files, 1.4MB)
# Removing: /usr/local/Cellar/xz/5.4.0... (95 files, 1.6MB)
# Removing: /usr/local/Cellar/xz/5.4.4... (163 files, 2.5MB)
# Removing: /Users/michaelmentele/Library/Caches/Homebrew/z3--4.12.2... (12.8MB)
# Removing: /usr/local/Cellar/zstd/1.5.2... (31 files, 3MB)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/postgresql@14... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/ruby@2.7... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/rust... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/gcc... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/openssl@3... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/ca-certificates... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/watchman... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/openssl@1.1... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/python@3.10... (2 files, 2.5KB)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/node... (64B)
# Removing: /Users/michaelmentele/Library/Logs/Homebrew/python@3.11... (2 files, 2.5KB)
# Pruned 0 symbolic links and 18 directories from /usr/local
# ==> Caveats
# ==> cmake
# To install the CMake documentation, run:
#   brew install cmake-docs
#
# Emacs Lisp files have been installed to:
#   /usr/local/share/emacs/site-lisp/cmake
# ==> llm
# zsh completions have been installed to:
#   /usr/local/share/zsh/site-functions
# ==> rust
# zsh completions have been installed to:
#   /usr/local/share/zsh/site-functions

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip3 install 'gymnasium[atari]'
# !pip3 install 'gymnasium[accept-rom-license]'
# Out:
# Requirement already satisfied: gymnasium[atari] in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (0.29.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[atari]) (1.6.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[atari]) (1.24.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[atari]) (4.7.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[atari]) (7.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[atari]) (0.0.4)
# Collecting shimmy[atari]<1.0,>=0.1.0
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium[atari]) (3.5.0)
# Collecting ale-py~=0.8.1
#   Downloading ale_py-0.8.1-cp38-cp38-macosx_10_15_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 377 kB/s eta 0:00:01
# Requirement already satisfied: importlib-resources in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0->gymnasium[atari]) (6.1.1)
# Installing collected packages: shimmy, ale-py
# Successfully installed ale-py-0.8.1 shimmy-0.2.1
# Requirement already satisfied: gymnasium[accept-rom-license] in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (0.29.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (1.6.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (1.24.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (7.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (4.7.1)
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-resources in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (6.1.1)
# Requirement already satisfied: click in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (8.0.1)
# Requirement already satisfied: requests in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.26.0)
# Requirement already satisfied: tqdm in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (4.62.1)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      |████████████████████████████████| 434 kB 257 kB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: zipp>=0.5 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium[accept-rom-license]) (3.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (1.26.6)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=bdc316dcf060417aecd13539dd10f9e2aabefd63f2dd2108e90b09053c7b16d1
#   Stored in directory: /Users/michaelmentele/Library/Caches/pip/wheels/84/55/09/367b3a18e3c0cf9c69af93d77818a6ea19493121c65af499f6
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
#!brew install python-opengl
# !pip3 install pyopengl
#!brew install xvfb
# !brew install XQuartz
# !pip3 install pyvirtualdisplay
# Out:
# Requirement already satisfied: pyopengl in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (3.1.7)
# ==> Downloading https://github.com/XQuartz/XQuartz/releases/download/XQuartz-2.8
# ==> Downloading from https://objects.githubusercontent.com/github-production-rel
# ######################################################################### 100.0%
# ==> Installing Cask xquartz
# ==> Running installer for xquartz with sudo; the password may be necessary.
# Password:
#
# Requirement already satisfied: pyvirtualdisplay in /Users/michaelmentele/opt/anaconda3/lib/python3.8/site-packages (3.0)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/d8/n91dxjpx127f7sdxww2g2m2c0000gn/T/ipykernel_67889/2040972422.py in <module>
#       2 from pyvirtualdisplay import Display
#       3
# ----> 4 virtual_display = Display(visible=0, size=(1400, 900))
#       5 virtual_display.start()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyvirtualdisplay/display.py in __init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, retries, extra_args, manage_global_env, **kwargs)
#      52             raise ValueError("unknown backend: %s" % self._backend)
#      53
# ---> 54         self._obj = cls(
#      55             size=size,
#      56             color_depth=color_depth,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyvirtualdisplay/xvfb.py in __init__(self, size, color_depth, bgcolor, use_xauth, fbdir, dpi, retries, extra_args, manage_global_env)
#      42         self._dpi = dpi
#      43
# ---> 44         AbstractDisplay.__init__(
#      45             self,
#      46             PROGRAM,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyvirtualdisplay/abstractdisplay.py in __init__(self, program, use_xauth, retries, extra_args, manage_global_env)
#      83         self._retries_current = 0
#      84
# ---> 85         helptext = get_helptext(program)
#      86         self._has_displayfd = "-displayfd" in helptext
#      87         if not self._has_displayfd:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyvirtualdisplay/util.py in get_helptext(program)
#      11
#      12     # py3.6 also
# ---> 13     p = subprocess.Popen(
#      14         cmd,
#      15         stdout=subprocess.PIPE,
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     856                             encoding=encoding, errors=errors)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#     860                                 startupinfo, creationflags, shell,
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1704                     if errno_num != 0:
#    1705                         err_msg = os.strerror(errno_num)
# -> 1706                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1707                 raise child_exception_type(err_msg)
#    1708
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Xvfb'

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name _____________________ -orga _____________________ -f logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
